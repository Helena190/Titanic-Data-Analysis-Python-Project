# %%
import pandas  as pd

# %%
df = pd.read_csv("https://raw.githubusercontent.com/atlantico-academy/datasets/main/titanic.csv")
df.head()
# Out:
#    survived  pclass     sex   age  sibsp  parch     fare embarked  class  \
# 0         0       3    male  22.0      1      0   7.2500        S  Third
# 1         1       1  female  38.0      1      0  71.2833        C  First
# 2         1       3  female  26.0      0      0   7.9250        S  Third
# 3         1       1  female  35.0      1      0  53.1000        S  First
# 4         0       3    male  35.0      0      0   8.0500        S  Third
#
#      who  adult_male deck  embark_town alive  alone
# 0    man        True  NaN  Southampton    no  False
# 1  woman       False    C    Cherbourg   yes  False
# 2  woman       False  NaN  Southampton   yes   True
# 3  woman       False    C  Southampton   yes  False
# 4    man        True  NaN  Southampton    no   True

# %%
df.to_csv("../data/raw/data.csv", index=False)

# %%
dicionario = pd.DataFrame([
 {
        'variavel': 'survived',
        'descricao': 'Indica se o passageiro sobreviveu (1) ou não (0).',
        'tipo': 'qualitativa',
        'subtipo': 'nominal'
    },
     {
        'variavel': 'pclass',
        'descricao': 'Classe do bilhete do passageiro (1 = Primeiro, 2 = Segundo, 3 = Terceiro).',
        'tipo': 'qualitativa',
        'subtipo': 'ordinal'
    },
    {
        'variavel': 'sex',
        'descricao': 'Sexo do passageiro (male = masculino, female = feminino).',
        'tipo': 'qualitativa',
        'subtipo': 'nominal'
    },
    {
        'variavel': 'age',
        'descricao': 'Idade do passageiro em anos.',
        'tipo': 'quantitativa',
        'subtipo': 'contínua'
    },
    {
        'variavel': 'sibsp',
        'descricao': 'Número de irmãos ou cônjuges a bordo.',
        'tipo': 'quantitativa',
        'subtipo': 'discreta'
    },
    {
        'variavel': 'parch',
        'descricao': 'Número de pais ou filhos a bordo.',
        'tipo': 'quantitativa',
        'subtipo': 'discreta'
    },
    {
        'variavel': 'fare',
        'descricao': 'Tarifa paga pelo passageiro.',
        'tipo': 'quantitativa',
        'subtipo': 'contínua'
    },
   {
        'variavel': 'embarked',
        'descricao': 'Porto de embarque do passageiro (C = Cherbourg, Q = Queenstown, S = Southampton).',
        'tipo': 'qualitativa',
        'subtipo': 'nominal'
    },
   {
        'variavel': 'class',
        'descricao': 'Classe do bilhete do passageiro (First, Second, Third).',
        'tipo': 'qualitativa',
        'subtipo': 'ordinal'
    },
   {
        'variavel': 'who',
        'descricao': 'Categoria do passageiro (man = homem, woman = mulher, child = criança).',
        'tipo': 'qualitativa',
        'subtipo': 'nominal'
    },
    {
        'variavel': 'adult_male',
        'descricao': 'Indica se o passageiro é um adulto do sexo masculino (True) ou não (False).',
        'tipo': 'qualitativa',
        'subtipo': 'nominal'
    },
    {
        'variavel': 'deck',
        'descricao': 'Deck do navio onde o passageiro estava localizado.',
        'tipo': 'qualitativa',
        'subtipo': 'nominal'
    },
     {
        'variavel': 'embark_town',
        'descricao': 'Cidade de embarque do passageiro (Cherbourg, Queenstown, Southampton).',
        'tipo': 'qualitativa',
        'subtipo': 'nominal'
    },
    {
        'variavel': 'alive',
        'descricao': 'Indica se o passageiro está vivo (yes) ou não (no).',
        'tipo': 'qualitativa',
        'subtipo': 'nominal'
    },
    {
        'variavel': 'alone',
        'descricao': 'Indica se o passageiro estava sozinho (True) ou acompanhado (False).',
        'tipo': 'qualitativa',
        'subtipo': 'nominal'
    }

])
dicionario
# Out:
#        variavel                                          descricao  \
# 0      survived  Indica se o passageiro sobreviveu (1) ou não (0).
# 1        pclass  Classe do bilhete do passageiro (1 = Primeiro,...
# 2           sex  Sexo do passageiro (male = masculino, female =...
# 3           age                       Idade do passageiro em anos.
# 4         sibsp              Número de irmãos ou cônjuges a bordo.
# 5         parch                  Número de pais ou filhos a bordo.
# 6          fare                       Tarifa paga pelo passageiro.
# 7      embarked  Porto de embarque do passageiro (C = Cherbourg...
# 8         class  Classe do bilhete do passageiro (First, Second...
# 9           who  Categoria do passageiro (man = homem, woman = ...
# 10   adult_male  Indica se o passageiro é um adulto do sexo mas...
# 11         deck  Deck do navio onde o passageiro estava localiz...
# 12  embark_town  Cidade de embarque do passageiro (Cherbourg, Q...
# ...

# %%
dicionario.to_csv("../data/external/dictionary.csv", index=False)
